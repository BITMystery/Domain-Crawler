# %% [markdown]
# My first crawler - craw all rent info (address, price, #bedroom, #bathroom, #parking) of a list of suburbs in Sydney from https://www.domain.com.au.
#
# Tools: requests, bs4

# %%
import requests

# %% [markdown]
# Test requests.get(), considering the first result page of a specific region 'Ashfield NSW 2131' only.

# %%
url = 'https://www.domain.com.au/rent/ashfield-nsw-2131'
r = requests.get(url)
r.text
# Out:
# u'<!DOCTYPE html><html lang="en-AU" data-tag="v1.0.1" data-commit-id="927b694a4ec0916eb8b5565a0ee6671ead215883"><head><meta charset="utf-8"/><meta http-equiv="content-language" content="en-au"/><meta name="format-detection" content="telephone=no"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no"/><link rel="dns-prefetch" href="//static.domain.com.au"/><link rel="dns-prefetch" href="//images.domain.com.au"/><link rel="dns-prefetch" href="//fonts.gstatic.com"/><link rel="dns-prefetch" href="//b.domainstatic.com.au"/><link rel="dns-prefetch" href="//mt0.googleapis.com"/><link rel="dns-prefetch" href="//mt1.googleapis.com"/><link rel="dns-prefetch" href="//assets.adobedtm.com"/><link rel="dns-prefetch" href="//renderizr-assets.domainstatic.com.au"/><meta name="apple-mobile-web-app-capable" content="yes"/><meta name="apple-itunes-app" content="app-id=319908646, affiliate-data=270216&amp;amp;ct=smartbanner_Homepage, app-argument=domain.com.au://open?AdId=2012349010"/><link rel="alternate" href="android-app://com.fairfax.domain/https/www.domain.com.au/"/><link rel="alternate" href="ios-app://319908646/domain.com.au/domainapp"/><link rel="apple-touch-icon-precomposed" href="https://static.domain.com.au/domain/54.png"/><link rel="apple-touch-icon-precomposed" href="https://static.domain.com.au/domain/72.png"/><link rel="apple-touch-icon-precomposed" href="https://static.domain.com.au/domain/114.png"/><link rel="apple-touch-icon-precomposed" href="https://static.domain.com.au/domain/144.png"/><link rel="shortcut icon" href="https://static.domain.com.au/domain/favicon.ico"/><title>116 Rental Properties in Ashfield, NSW, 2131</title><meta name="description" content="Domain has 116 Rental Properties in Ashfield, NSW, 2131. View our listings &amp; use our detailed filters to find your perfect home."/><link rel="manifest" href="/manifest.json"/><meta name="theme-color" content="#0ea800"/><link rel="canonical" href="https://www.domain.com.au/rent/ashfield-nsw-2131/"/><link href="https://static.domain.com.au/content/fe-static/@domain-group/fe-brary/css/fe-brary-globals_8cea6a1cdc522934.css" type="text/css" rel="stylesheet"/><link href="/phoenix/assets/components/@domain-group/fe-pa-search-results/@domain-group_fe-pa-search-results_0.0.0_59aecd68cbd7ea1b_client-domain.css" type="text/css" rel="stylesheet"/><noscript><style>.expander__gradient { display: none !important; } .expander-content { height: auto !important; }</style></noscript><script type="application/ld+json">[{"@context":"http://schema.org","@type":"Organization","name":"Domain","url":"https://www.domain.com.au","sameAs":["https://www.facebook.com/domain.com.au","https://twitter.com/domaincomau","https://plus.google.com/+domaincomau","https://www.linkedin.com/company/domain-com-au"]},{"@context":"http://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"@id":"https://www.domain.com.au/","name":"Home"}},{"@type":"ListItem","position":2,"item":{"@id":"https://www.domain.com.au/rent/nsw/","name":"NSW"}},{"@type":"ListItem","position":3,"item":{"@id":"https://www.domain.com.au/rent/ashfield-nsw-2131/","name":"Ashfield"}}]}]</script><link rel="next" href="https://www.domain.com.au/rent/ashfield-nsw-2131/?page=2"/></head><body><noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-M3HVG4" height="0" width="0" style="display:none;visibility:hidden;"></iframe></noscript><div><div class="__domain_group_fe_pa_search_results___0_0_0" data-renderizr-id="page"><div class="search-results" data-reactid=".5gxkpn7qf8" data-react-checksum="-931323732"><div class="search-results__leaderboard" data-reactid=".5gxkpn7qf8.0"><div class="adspot__wrapper search-results__ads-block adspot-468x60_728x90-pos-1-container" data-reactid=".5gxkpn7qf8.0.0"><span data-reactid=".5gxkpn7qf8.0.0.0"><div class="adspot-468x60_728x90-pos-1-fallback se ...

# %% [markdown]
# Parse an HTML text using BeautifilSoup.
#
# If the HTML text is not formatted well, try some online formatter such as https://www.freeformatter.com/html-formatter.html.

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(r.text)

# %%
items = soup.findAll('li', {'class': 'search-results__listing'})
test_item = items[3]

# %% [markdown]
# Extract price.

# %%
price = test_item.find('p')
price.get_text()
# Out:
# u'DEPOSIT TAKEN '

# %% [markdown]
# Extract address.

# %%
address = test_item.find('a')
address.get_text()
# Out:
# u'12/61-63 Frederick Street,ASHFIELD NSW 2131'

# %% [markdown]
# Extract number of bedrooms.

# %%
facilities = test_item.findAll('span', {'class': 'property-feature__feature'})
bedroom_num = facilities[0].get_text()
bathroom_num = facilities[1].get_text()
parking_num = facilities[2].get_text()
print bedroom_num, bathroom_num, parking_num
# Out:
# 3 Beds 1 Bath 1 Parking

# %% [markdown]
# Extract all rent info.

# %%
info_list = []
for item in items:
    address = item.find('a')
    price = item.find('p')
    facilities = item.findAll('span', {'class': 'property-feature__feature'})
    if len(facilities) != 3:
        continue
    [bedroom_num, bathroom_num, parking_num] = facilities
    if address and price and bedroom_num and bathroom_num and parking_num:
        info_list.append([
            address.get_text(),
            price.get_text(),
            bedroom_num.get_text(),
            bathroom_num.get_text(),
            parking_num.get_text()
        ])
info_list
# Out:
# [[u'406/1 Victoria Street,ASHFIELD NSW 2131',
#   u'$560 ',
#   u'1 Bed',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'G07/1 Victoria St,ASHFIELD NSW 2131',
#   u'$575 ',
#   u'1 Bed',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'12/61-63 Frederick Street,ASHFIELD NSW 2131',
#   u'DEPOSIT TAKEN ',
#   u'3 Beds',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'B101/11-13 Hercules Street,ASHFIELD NSW 2131',
#   u'DEPOSIT TAKEN ',
#   u'1 Bed',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'43 Service Avenue,ASHFIELD NSW 2131',
#   u'$820 PER WEEK ',
#   u'3 Beds',
#   u'2 Baths',
#   u'4 Parkings'],
#  [u'1/90 Victoria Street,ASHFIELD NSW 2131',
#   u'$600 per week ',
#   u'2 Beds',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'3/53 Gower Street,ASHFIELD NSW 2131',
#   u'$550 ',
#   u'2 Beds',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'18/371-377 Liverpool Road,ASHFIELD NSW 2131',
#   u'$530 ',
#   u'1 Bed',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'4/37 Alt Street,ASHFIELD NSW 2131',
#   u'$880 to $900 ',
#   u'3 Beds',
#   u'2 Baths',
#   u'2 Parkings'],
#  [u'9/2A Brown Street,ASHFIELD NSW 2131',
#   u'$670 ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'143/18-20 Knocklayde Street,ASHFIELD NSW 2131',
#   u'$650-$670 Per Week ',
#   u'3 Beds',
#   u'2 Baths',
#   u'2 Parkings'],
#  [u'10/40-42 Chandos Street,ASHFIELD NSW 2131',
#   u'$630 ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'17a Clissold Street,ASHFIELD NSW 2131',
#   u'$580-$600 Per Week ',
#   u'3 Beds',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'207/11-13 Hercules Street,ASHFIELD NSW 2131',
#   u'$535 ',
#   u'1 Bed',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'38/5 Benalla Avenue,ASHFIELD NSW 2131',
#   u'$520 ',
#   u'2 Beds',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'5/122 Frederick Street,ASHFIELD NSW 2131',
#   u'$400.00 ',
#   u'1 Bed',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'10/62 Elizabeth Street,ASHFIELD NSW 2131',
#   u'$400 per week ',
#   u'1 Bed',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'1/21 Alma Street,ASHFIELD NSW 2131',
#   u'$320 ',
#   u'1 Bed',
#   u'\u2212 0 Baths',
#   u'\u2212 0 Parkings'],
#  [u'4/102 Bland Street,ASHFIELD NSW 2131',
#   u'$300 per week ',
#   u'1 Bed',
#   u'1 Bath',
#   u'\u2212 0 Parkings'],
#  [u'11-13 Hercules Street,ASHFIELD NSW 2131',
#   u'$50 per week ',
#   u'\u2212 0 Beds',
#   u'\u2212 0 Baths',
#   u'1 Parking']]

# %% [markdown]
# Now let's craw all rent info for a list of suburbs.
#
# The following suburbs are selected according to popular suburbs for renting in http://www.sydneytoday.com/house_rent.

# %%
url = 'https://www.domain.com.au/rent/'

suburbs = [
    'ashfield-nsw-2131',
    'auburn-nsw-2144',
    'burwood-nsw-2134',
    'campsie-nsw-2194',
    'chatswood-nsw-2067',
    'eastwood-nsw-2122/',
    'epping-nsw-2121',
    'haymarket-nsw-2000',
    'hurstville-nsw-2220',
    'kingsford-nsw-2032',
    'marsfield-nsw-2122',
    'mascot-nsw-2020',
    'parramatta-nsw-2150',
    'rhodes-nsw-2138',
    'strathfield-nsw-2135',
    'sydney-nsw-2000',
    'ultimo-nsw-2007',
    'waterloo-nsw-2017',
    'zetland-nsw-2017'
]

# %% [markdown]
# Note that there would be multiple result pages for each suburb.

# %%
suburb_rent_info = {}
for suburb in suburbs:
    suburb_name = suburb.split('-')[0]
    print 'Processing %s...' % suburb_name
    suburb_url = url + suburb
    info_list = []
    
    page = 1
    while True:
        url_full = suburb_url + '/?page=' + str(page)
        r = requests.get(url_full)
        soup = BeautifulSoup(r.text)
        items = soup.findAll('li', {'class': 'search-results__listing'})
        if not items:
            break
        for item in items:
            address = item.find('a')
            price = item.find('p')
            facilities = item.findAll('span', {'class': 'property-feature__feature'})
            if len(facilities) != 3:
                continue
            [bedroom_num, bathroom_num, parking_num] = facilities
            if address and price and bedroom_num and bathroom_num and parking_num:
                info_list.append([
                    address.get_text(),
                    price.get_text(),
                    bedroom_num.get_text(),
                    bathroom_num.get_text(),
                    parking_num.get_text()
                ])
        page += 1
    
    suburb_rent_info[suburb_name] = info_list
# Out:
# Processing ashfield...
# Processing auburn...
# Processing burwood...
# Processing campsie...
# Processing chatswood...
# Processing eastwood...
# Processing epping...
# Processing haymarket...
# Processing hurstville...
# Processing kingsford...
# Processing marsfield...
# Processing mascot...
# Processing parramatta...
# Processing rhodes...
# Processing strathfield...
# Processing sydney...
# Processing ultimo...
# Processing waterloo...
# Processing zetland...

# %%
for suburb_name, info_list in suburb_rent_info.items():
    print '%s has %d results'% (suburb_name, len(info_list))
# Out:
# haymarket has 29 results
# burwood has 92 results
# waterloo has 89 results
# kingsford has 87 results
# strathfield has 111 results
# rhodes has 97 results
# parramatta has 224 results
# zetland has 79 results
# epping has 162 results
# auburn has 84 results
# marsfield has 45 results
# chatswood has 202 results
# ashfield has 116 results
# sydney has 212 results
# eastwood has 64 results
# campsie has 112 results
# ultimo has 27 results
# hurstville has 74 results
# mascot has 106 results

# %%
suburb_rent_info['rhodes']
# Out:
# [[u'402/12 Shoreline Dr,RHODES NSW 2138',
#   u'$700 wk ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'205/11 Lewis Ave,RHODES NSW 2138',
#   u'$700 wk ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'601/36 Shoreline Drive,RHODES NSW 2138',
#   u'$550 wk ',
#   u'1 Bed',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'10/24 Walker St,RHODES NSW 2138',
#   u'$540 wk ',
#   u'1 Bed',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'L6 AND L11/52-54 Walker st,RHODES NSW 2138',
#   u'$850 to $880 ',
#   u'3 Beds',
#   u'2 Baths',
#   u'2 Parkings'],
#  [u'721/4 Marquet Street,RHODES NSW 2138',
#   u'$800 ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'712/3 Timbrol Ave,RHODES NSW 2138',
#   u'$730 wk ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'705/52-54 WALKER STREET,RHODES NSW 2138',
#   u'$720 ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'113/56-58 Walker Street,RHODES NSW 2138',
#   u'$700 ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'405/44 Shoreline Drive,RHODES NSW 2138',
#   u'$695 ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'1107/52-54 WALKER STREET,RHODES NSW 2138',
#   u'$670 ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'18/85 Shoreline drive,RHODES NSW 2138',
#   u'$650 ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'207/52-54 Walker St,RHODES NSW 2138',
#   u'$550 ',
#   u'1 Bed',
#   u'1 Bath',
#   u'\u2212 0 Parkings'],
#  [u'114/38 Shoreline Drive,RHODES NSW 2138',
#   u'$670 ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'36 Shoreline Drive,RHODES NSW 2138',
#   u'$490 ',
#   u'1 Bed',
#   u'1 Bath',
#   u'\u2212 0 Parkings'],
#  [u'2308/46 Walker St,RHODES NSW 2138',
#   u'$900plus or Offer ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'201/88 Rider Boulevard,RHODES NSW 2138',
#   u'$700 ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'735/4 Marquet Street,RHODES NSW 2138',
#   u'$680 ',
#   u'2 Beds',
#   u'2 Baths',
#   u'2 Parkings'],
#  [u'701/87 Shoreline Drive,RHODES NSW 2138',
#   u'$680 ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'2210/42 Walker Street,RHODES NSW 2138',
#   u'$680.00 ',
#   u'2 Beds',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'201/2 Rider Blvd,RHODES NSW 2138',
#   u'Application Approved, Inspection Cancelled ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'202/1 Gauthorpe St,RHODES NSW 2138',
#   u'Application approved, inspection cancelled ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'402/63 Shoreline Drive,RHODES NSW 2138',
#   u'$660 per week ',
#   u'2 Beds',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'86 Rider Blvd,RHODES NSW 2138',
#   u'TBA ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'31 Blaxland Road,RHODES NSW 2138',
#   u'$600 ',
#   u'2 Beds',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'606/2 Walker St,,RHODES NSW 2138',
#   u'TBA ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'507/2 Lewis Ave,RHODES NSW 2138',
#   u'$560 ',
#   u'1 Bed',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'502/18 Walker St,RHODES NSW 2138',
#   u'$540 ',
#   u'1 Bed',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'102/18 Walker St,RHODES NSW 2138',
#   u'$520 ',
#   u'1 Bed',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'B208/3 Timbrol Avenue,RHODES NSW 2138',
#   u'$520.00 ',
#   u'1 Bed',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'407/2 Lewis Avenue,RHODES NSW 2138',
#   u'***Deposit Taken*** ',
#   u'1 Bed',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'45 Blaxland Road,RHODES NSW 2138',
#   u'$495 ',
#   u'1 Bed',
#   u'1 Bath',
#   u'\u2212 0 Parkings'],
#  [u'13/24 Walker St,RHODES NSW 2138',
#   u'$430 ',
#   u'1 Bed',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'402/42 Shoreline Drive,RHODES NSW 2138',
#   u'$720 per week ',
#   u'2 Beds',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'41 Blaxland Road,RHODES NSW 2138',
#   u'$650 per week ',
#   u'3 Beds',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'A404/10-16 Marquet Street,RHODES NSW 2138',
#   u'$550 per week ',
#   u'1 Bed',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'519/6 Marquet St,RHODES NSW 2138',
#   u'Deposit Taken ',
#   u'1 Bed',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'4 Rider Boulevard,RHODES NSW 2138',
#   u'$1400-$1500 ',
#   u'3 Beds',
#   u'2 Baths',
#   u'2 Parkings'],
#  [u'214/11 Lewis Avenue,RHODES NSW 2138',
#   u'$1,000 ',
#   u'3 Beds',
#   u'2 Baths',
#   u'2 Parkings'],
#  [u'86/1 Timbrol Avenue,RHODES NSW 2138',
#   u'$1,000 ',
#   u'3 Beds',
#   u'2 Baths',
#   u'2 Parkings'],
#  [u'1705/63 Shoreline Drive,RHODES NSW 2138',
#   u'$950 per week ',
#   u'3 Beds',
#   u'2 Baths',
#   u'2 Parkings'],
#  [u'79 Shoreline Drive,RHODES NSW 2138',
#   u'$750 Furnished ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'A310/40 Shoreline Dr,RHODES NSW 2138',
#   u'FREE 1 WEEK RENT ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'404/2 Shoreline Drive,RHODES NSW 2138',
#   u'$700 ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'1412/43 Shoreline Drive,RHODES NSW 2138',
#   u'$700 ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'Level 4, 406/16 Sevier Avenue,RHODES NSW 2138',
#   u'$700 ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'1105/7 Rider Boulevard,RHODES NSW 2138',
#   u'$700 ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'751/2 Marquet  Street,RHODES NSW 2138',
#   u'$690 ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'Level 6/80 Rider Boulevard,RHODES NSW 2138',
#   u'$690 ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'407/63 Shoreline Drive,RHODES NSW 2138',
#   u'$680 ',
#   u'2 Beds',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'30/2 Nina Grey Ave,RHODES NSW 2138',
#   u'$680 wk ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'502/76 Rider Blvd,RHODES NSW 2138',
#   u'*** Deposit Taken *** ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'509/46 Walker Street,RHODES NSW 2138',
#   u'Deposit taken ',
#   u'2 Beds',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'302/11 Shoreline Drive,RHODES NSW 2138',
#   u'$680 ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'10/7 Cropley Street,RHODES NSW 2138',
#   u'$675 ',
#   u'2 Beds',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'404/88 Rider Boulevard,RHODES NSW 2138',
#   u'*** DEPOSIT TAKEN *** ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'730/60 walker st,RHODES NSW 2138',
#   u'$670 ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'B402/10-16 Marquet st,RHODES NSW 2138',
#   u'Deposit Taken,Thank you ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'205 2 Lewis Avenue,RHODES NSW 2138',
#   u'$700 per week ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'189/38 Shoreline Drive,RHODES NSW 2138',
#   u'$660 ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'101/12 Shoreline Drive,RHODES NSW 2138',
#   u'$660 ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'116/56-58 Walker St,RHODES NSW 2138',
#   u'DEPOSIT TAKEN, INSPECTION CANCELLED ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'15 Cavell Avenue,RHODES NSW 2138',
#   u'$645 per week ',
#   u'4 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'2  Marquet Street,RHODES NSW 2138',
#   u'$650 ',
#   u'2 Beds',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'65/50 Walker St,RHODES NSW 2138',
#   u'$640 per Week ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'77/50 Walker Street,RHODES NSW 2138',
#   u'$640 ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'D208/10-16 Marquet,RHODES NSW 2138',
#   u'$630 ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'79/38 Shoreline Drive,RHODES NSW 2138',
#   u'630  negotiate ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'2204/42 Walker Street,RHODES NSW 2138',
#   u'$610.00 ',
#   u'1 Bed',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'204/46 Walker Street,RHODES NSW 2138',
#   u'$610 ',
#   u'2 Beds',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'2106/42 Walker Street,RHODES NSW 2138',
#   u'$600.00 ',
#   u'1 Bed',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'1106/7 Rider Boulevard,RHODES NSW 2138',
#   u'$580 ',
#   u'1 Bed',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'A811/40 Shoreline Drive,RHODES NSW 2138',
#   u'$580 wk ',
#   u'2 Beds',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'C503/10-16 Marquet Street,RHODES NSW 2138',
#   u'$560 ',
#   u'1 Bed',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'807/7 Rider Boulevard,RHODES NSW 2138',
#   u'$560 ',
#   u'1 Bed',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'1509/43 Shoreline Drive,RHODES NSW 2138',
#   u'$560 to $570 ',
#   u'1 Bed',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'201/76 Rider Boulevard,RHODES NSW 2138',
#   u'Contact Agent ',
#   u'1 Bed',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'23/1 Timbrol Avenue,RHODES NSW 2138',
#   u'$530 per week ',
#   u'1 Bed',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'GG04/10-16 Marquet Street,RHODES NSW 2138',
#   u'***DEPOSIT TAKEN*** ',
#   u'2 Beds',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'201/43 Shoreline Drive,RHODES NSW 2138',
#   u'$520 ',
#   u'1 Bed',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'305/5 Nina Gray Avenue,RHODES NSW 2138',
#   u'$510 ',
#   u'1 Bed',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'206/7 Rider Boulevard,RHODES NSW 2138',
#   u'$500 PET FRIENDLY ',
#   u'\u2212 0 Beds',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'1310/46 Walker Street,RHODES NSW 2138',
#   u'$500.00 Per Week application received ',
#   u'1 Bed',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'G107/10-16 Marquet Street,RHODES NSW 2138',
#   u'$500 ',
#   u'1 Bed',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'45/50 Walker Street,RHODES NSW 2138',
#   u'$500 ',
#   u'1 Bed',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'2 Nina Gray Ave,RHODES NSW 2138',
#   u'$460 ',
#   u'1 Bed',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'10 CAVELL AVENUE,RHODES NSW 2138',
#   u'$410 ',
#   u'2 Beds',
#   u'1 Bath',
#   u'2 Parkings'],
#  [u'L2/10-16 Marquet St,RHODES NSW 2138',
#   u'TBA or Offer ',
#   u'3 Beds',
#   u'2 Baths',
#   u'2 Parkings'],
#  [u'183/4 Timbrol Avenue,RHODES NSW 2138',
#   u'$680 per week ',
#   u'2 Beds',
#   u'2 Baths',
#   u'2 Parkings'],
#  [u'205/16 Sevier Avenue,RHODES NSW 2138',
#   u'$690 ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'620/89 Shoreline Drive,RHODES NSW 2138',
#   u'$665 per week ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'1607/63 Shoreline Drive,RHODES NSW 2138',
#   u'$640 ',
#   u'2 Beds',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'326/60 Walker Street,RHODES NSW 2138',
#   u'$620 per week ',
#   u'2 Beds',
#   u'2 Baths',
#   u'1 Parking'],
#  [u'43 Shoreline Drive,RHODES NSW 2138',
#   u'$570 ',
#   u'1 Bed',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'708/63 Shoreline Drive,RHODES NSW 2138',
#   u'$560 ',
#   u'1 Bed',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'A304/10-16 Marquet Street,RHODES NSW 2138',
#   u'$530 ',
#   u'1 Bed',
#   u'1 Bath',
#   u'1 Parking'],
#  [u'Level 1, C101/10 - 16 Marquet  Street,RHODES NSW 2138',
#   u'$460 ',
#   u'1 Bed',
#   u'1 Bath',
#   u'\u2212 0 Parkings']]

# %% [raw]
# From the result we can see that the format of rent info is not uniform.
#
# E.g., some prices contain 'PW' or 'Per Week' while some are not.
#
# Write a function data_format to format them.

# %%
def data_format(suburb_rent_info):
    formatted_suburb_rent_info = []
    for suburb_name, info_list in suburb_rent_info.items():
        for rent_info in info_list:
            try:
                address = rent_info[0].split(',')
                address = ' '.join(address)
                
                price = filter(lambda c: c in '1234567890-.', rent_info[1])
                if len(price) <= 1:
                    price = None
                else:
                    if '-' in price:
                        price = price.split('-')[0]
                    price = price.split('.')[0]
                    if not price:
                        price = None
                    else:
                        price = int(price)
                    if price > 10000:
                        price = None
                
                bedroom_num = rent_info[2].split()[0]
                if not bedroom_num.isdigit():
                    bedroom_num = None
                else:
                    bedroom_num = int(bedroom_num)
                
                bathroom_num = rent_info[3].split()[0]
                if not bathroom_num.isdigit():
                    bathroom_num = None
                else:
                    bathroom_num = int(bathroom_num)
                
                parking_num = rent_info[4].split()[0]
                if not parking_num.isdigit():
                    parking_num = None
                else:
                    parking_num = int(parking_num)
            except ValueError as e:
                print e
                print rent_info
            formatted_suburb_rent_info.append((suburb_name, address, price, bedroom_num, bathroom_num, parking_num))
    
    return formatted_suburb_rent_info

# %%
formatted_suburb_rent_info = data_format(suburb_rent_info)

# %% [markdown]
# Write formatted data into a csv file.

# %%
import csv

# %%
headers = ['Suburb','Address','Price','Bedrooms','Bathrooms','Parkings']

with open('rent_info.csv','w') as f:
    f_csv = csv.writer(f)
    f_csv.writerow(headers)
    f_csv.writerows(formatted_suburb_rent_info)

# %% [markdown]
# Now we are ready to analyse the data.

# %%
import pandas as pd

# %%
data = pd.read_csv('rent_info.csv')
data
# Out:
#          Suburb                                            Address   Price  \
# 0     haymarket      Level 18/178 Thomas Street HAYMARKET NSW 2000  1200.0
# 1     haymarket          303 Castlereagh Street HAYMARKET NSW 2000  1050.0
# 2     haymarket          Level 32/2 Quay Street HAYMARKET NSW 2000   580.0
# 3     haymarket          S909/178 Thomas Street HAYMARKET NSW 2000     NaN
# 4     haymarket         Level 33/2 Quay  Street HAYMARKET NSW 2000   920.0
# 5     haymarket  S16.10/178 Thomas Street Street HAYMARKET NSW ...   990.0
# 6     haymarket             N905/33 Ultimo Road HAYMARKET NSW 2000   790.0
# 7     haymarket              1708/2 Quay Street HAYMARKET NSW 2000  1000.0
# 8     haymarket        1601/6 Little Hay Street HAYMARKET NSW 2000   760.0
# 9     haymarket                   178 Thomas st HAYMARKET NSW 2000     NaN
# 10    haymarket                                 HAYMARKET NSW 2000  1450.0
# 11    haymarket              2311/2 Quay street HAYMARKET NSW 2000  1200.0
# 12    haymarket               1 Steam Mill Lane HAYMARKET NSW 2000  1000.0
# 13    haymarket                        416 Pitt HAYMARKET NSW 2000  1000.0
# 14    haymarket     2011/53 Tumbalong Boulevard HAYMARKET NSW 2000   990.0
# 15    haymarket     2043/53 Tumbalong Boulevard HAYMARKET NSW 2000   850.0
# 16    haymarket         803/6 Little Hay Street HAYMARKET NSW 2000   750.0
# 17    haymarket            6  Little Hay Street HAYMARKET NSW 2000   740.0
# 18    haymarket         L26/91 Liverpool Street HAYMARKET NSW 2000   720.0
# 19    haymarket     2022/53 Tumbalong Boulevard HAYMARKET NSW 2000   720.0
# 20    haymarket           Lv 15/6 Little Hay St HAYMARKET NSW 2000   710.0
# 21    haymarket           302/178 Thomas Street HAYMARKET NSW 2000   600.0
# 22    haymarket              2706/2 Quay Street HAYMARKET NSW 2000   600.0
# 23    haymarket                   2 Quay Street HAYMARKET NSW 2000   580.0
# 24    haymarket  107 Quay St  Haymarket  New South Wales  Austr...   570.0
# 25    haymarket      Carspace 178 Thomas Street HAYMARKET NSW 2000   100.0
# 26    haymarket            N1206/33 Ultimo Road HAYMARKET NSW 2000   780.0
# 27    haymarket            N8.09/33 ULTIMO ROAD HAYMARKET NSW 2000   715.0
# 28    haymarket              N1509/33 Ultimo Rd HAYMARKET NSW 2000   695.0
# 29      burwood              273/1 Railway Parade BURWOOD NSW 2134   480.0
# ...         ...                                                ...     ...
# 1982     mascot                   811/39 Kent Road MASCOT NSW 2020   680.0
# 1983     mascot                   504/39 Kent Road MASCOT NSW 2020     NaN
# 1984     mascot           106/149 O'Riordan Street MASCOT NSW 2020     NaN
# 1985     mascot                 137/3-9 Church Ave MASCOT NSW 2020   630.0
# 1986     mascot               503B/8 Bourke Street MASCOT NSW 2020     NaN
# 1987     mascot              1271-1277 Botany Road MASCOT NSW 2020   620.0
# 1988     mascot               402C/8 Bourke Street MASCOT NSW 2020     NaN
# 1989     mascot               806C/8 Bourke Street MASCOT NSW 2020     NaN
# 1990     mascot                      412/9 John st MASCOT NSW 2020   600.0
# 1991     mascot                   16/228 Coward St MASCOT NSW 2020     NaN
# 1992     mascot               9/629 Gardeners Road MASCOT NSW 2020   585.0
# 1993     mascot             63/22 Tunbridge Street MASCOT NSW 2020   580.0
# 1994     mascot                  4/183 King Street MASCOT NSW 2020   550.0
# 1995     mascot                 21/919 Botany Road MASCOT NSW 2020   480.0
# 1996     mascot              10/2 MacIntosh Street MASCOT NSW 2020   460.0
# 1997     mascot                  1/3 Wentworth Ave MASCOT NSW 2020   325.0
# 1998     mascot                        King Street MASCOT NSW 2020   225.0
# 1999     mascot           Cage47/214-220 Coward St MASCOT NSW 2020   130.0
# 2000     mascot               958/61 Church Avenue MASCOT NSW 2020  1000.0
# 2001     mascot                  19 Carinya Avenue MASCOT NSW 2020   670.0
# 2002     mascot               558/61 Church Avenue MASCOT NSW 2020     NaN
# 2003     mascot      1001/103-105 O'Riordan Street MASCOT NSW 2020  1040.0
# 2004     mascot               363/61 Church Avenue MASCOT NSW 2020     NaN
# 2005     mascot                       39 Kent Road MASCOT NSW 2020     NaN
# 2006     mascot                  30/22 High Street MASCOT NSW 2020   750.0
# 2007     mascot                  504/7 John Street MASCOT NSW 2020     NaN
# 2008     mascot                                    MASCOT NSW 2020   670.0
# 2009     mascot                   104A/9 Kent Road MASCOT NSW 2020   650.0
# 2010     mascot                       39 Kent Road MASCOT NSW 2020     NaN
# 2011     mascot                 11A Tramway Street MASCOT NSW 2020   350.0
#
#       Bedrooms  Bathrooms  Parkings
# 0          2.0        2.0       2.0
# 1          2.0        2.0       1.0
# 2          1.0        1.0       NaN
# 3          2.0        2.0       1.0
# 4          2.0        2.0       1.0
# 5          2.0        2.0       1.0
# 6          1.0        1.0       1.0
# 7          2.0        2.0       1.0
# 8          1.0        1.0       NaN
# 9          2.0        2.0       NaN
# 10         2.0        2.0       1.0
# 11         2.0        2.0       1.0
# 12         2.0        2.0       1.0
# 13         2.0        2.0       NaN
# 14         2.0        2.0       1.0
# 15         1.0        1.0       1.0
# 16         1.0        1.0       NaN
# 17         1.0        1.0       NaN
# 18         1.0        1.0       1.0
# 19         1.0        1.0       NaN
# 20         1.0        1.0       NaN
# 21         1.0        1.0       NaN
# 22         1.0        1.0       NaN
# 23         1.0        1.0       NaN
# 24         1.0        1.0       NaN
# 25         NaN        NaN       2.0
# 26         1.0        1.0       1.0
# 27         1.0        1.0       NaN
# 28         1.0        1.0       NaN
# 29         1.0        1.0       1.0
# ...        ...        ...       ...
# 1982       1.0        1.0       1.0
# 1983       1.0        1.0       1.0
# 1984       1.0        1.0       1.0
# 1985       1.0        1.0       1.0
# 1986       1.0        1.0       1.0
# 1987       1.0        1.0       1.0
# 1988       1.0        1.0       1.0
# 1989       1.0        1.0       1.0
# 1990       1.0        1.0       1.0
# 1991       1.0        1.0       1.0
# 1992       1.0        1.0       1.0
# 1993       2.0        1.0       1.0
# 1994       2.0        1.0       1.0
# 1995       2.0        1.0       1.0
# 1996       2.0        1.0       1.0
# 1997       1.0        1.0       1.0
# 1998       3.0        2.0       NaN
# 1999       NaN        1.0       NaN
# 2000       3.0        2.0       2.0
# 2001       2.0        1.0       1.0
# 2002       3.0        2.0       2.0
# 2003       3.0        3.0       2.0
# 2004       2.0        2.0       1.0
# 2005       2.0        2.0       2.0
# 2006       3.0        2.0       2.0
# 2007       2.0        2.0       2.0
# 2008       3.0        1.0       NaN
# 2009       1.0        1.0       1.0
# 2010       1.0        1.0       1.0
# 2011       1.0        1.0       NaN
#
# [2012 rows x 6 columns]

# %%
target1 = data[data['Bedrooms'] == 1]
target2 = data[data['Bedrooms'] == 2]
target3 = data[data['Bedrooms'] == 3]
price1 = target1.groupby(['Suburb'])['Price'].mean()
price2 = target2.groupby(['Suburb'])['Price'].mean()
price3 = target3.groupby(['Suburb'])['Price'].mean()

# %%
compare = pd.DataFrame({'1 bedroom': price1, '2 bedrooms': price2, '3 bedrooms': price3})
compare
# Out:
#               1 bedroom   2 bedrooms   3 bedrooms
# ashfield     385.781250   528.979592   639.333333
# auburn       345.666667   464.459459   554.736842
# burwood      393.000000   613.513514   722.500000
# campsie      374.062500   502.714286   651.153846
# chatswood    599.313725   722.281250  1107.096774
# eastwood     313.750000   484.772727   618.863636
# epping       473.235294   547.685393   618.888889
# haymarket    697.500000  1080.000000          NaN
# hurstville   429.642857   517.592593   661.428571
# kingsford    399.687500   652.413793  1000.625000
# marsfield    480.000000   519.565217   630.909091
# mascot       565.238095   716.250000   890.227273
# parramatta   565.016667   570.518182   575.185185
# rhodes       529.444444   675.543478  1000.000000
# strathfield  428.500000   564.800000   715.500000
# sydney       705.512500  1142.924528  1828.823529
# ultimo       595.000000   870.000000  1490.000000
# waterloo     584.393939   759.117647  1057.857143
# zetland      610.000000   828.333333  1256.363636

# %%
price1.sort_values()
# Out:
# Suburb
# eastwood       313.750000
# auburn         345.666667
# campsie        374.062500
# ashfield       385.781250
# burwood        393.000000
# kingsford      399.687500
# strathfield    428.500000
# hurstville     429.642857
# epping         473.235294
# marsfield      480.000000
# rhodes         529.444444
# parramatta     565.016667
# mascot         565.238095
# waterloo       584.393939
# ultimo         595.000000
# chatswood      599.313725
# zetland        610.000000
# haymarket      697.500000
# sydney         705.512500
# Name: Price, dtype: float64

# %%
price2.sort_values()
# Out:
# Suburb
# auburn          464.459459
# eastwood        484.772727
# campsie         502.714286
# hurstville      517.592593
# marsfield       519.565217
# ashfield        528.979592
# epping          547.685393
# strathfield     564.800000
# parramatta      570.518182
# burwood         613.513514
# kingsford       652.413793
# rhodes          675.543478
# mascot          716.250000
# chatswood       722.281250
# waterloo        759.117647
# zetland         828.333333
# ultimo          870.000000
# haymarket      1080.000000
# sydney         1142.924528
# Name: Price, dtype: float64

# %%
price3.sort_values()
# Out:
# Suburb
# auburn          554.736842
# parramatta      575.185185
# eastwood        618.863636
# epping          618.888889
# marsfield       630.909091
# ashfield        639.333333
# campsie         651.153846
# hurstville      661.428571
# strathfield     715.500000
# burwood         722.500000
# mascot          890.227273
# rhodes         1000.000000
# kingsford      1000.625000
# waterloo       1057.857143
# chatswood      1107.096774
# zetland        1256.363636
# ultimo         1490.000000
# sydney         1828.823529
# Name: Price, dtype: float64

# %%
rhodes = data[(data['Suburb'] == 'rhodes') & (data['Bedrooms'] == 2)].sort_values('Price')
rhodes
# Out:
#      Suburb                                        Address  Price  Bedrooms  \
# 494  rhodes               10 CAVELL AVENUE RHODES NSW 2138  410.0       2.0
# 480  rhodes        A811/40 Shoreline Drive RHODES NSW 2138  580.0       2.0
# 432  rhodes               31 Blaxland Road RHODES NSW 2138  600.0       2.0
# 477  rhodes           204/46 Walker Street RHODES NSW 2138  610.0       2.0
# 500  rhodes           326/60 Walker Street RHODES NSW 2138  620.0       2.0
# 474  rhodes             D208/10-16 Marquet RHODES NSW 2138  630.0       2.0
# 475  rhodes          79/38 Shoreline Drive RHODES NSW 2138  630.0       2.0
# 499  rhodes        1607/63 Shoreline Drive RHODES NSW 2138  640.0       2.0
# 472  rhodes                65/50 Walker St RHODES NSW 2138  640.0       2.0
# 473  rhodes            77/50 Walker Street RHODES NSW 2138  640.0       2.0
# 471  rhodes              2  Marquet Street RHODES NSW 2138  650.0       2.0
# 419  rhodes          18/85 Shoreline drive RHODES NSW 2138  650.0       2.0
# 468  rhodes         101/12 Shoreline Drive RHODES NSW 2138  660.0       2.0
# 430  rhodes         402/63 Shoreline Drive RHODES NSW 2138  660.0       2.0
# 467  rhodes         189/38 Shoreline Drive RHODES NSW 2138  660.0       2.0
# 498  rhodes         620/89 Shoreline Drive RHODES NSW 2138  665.0       2.0
# 421  rhodes         114/38 Shoreline Drive RHODES NSW 2138  670.0       2.0
# 418  rhodes       1107/52-54 WALKER STREET RHODES NSW 2138  670.0       2.0
# 464  rhodes               730/60 walker st RHODES NSW 2138  670.0       2.0
# 462  rhodes            10/7 Cropley Street RHODES NSW 2138  675.0       2.0
# 425  rhodes           735/4 Marquet Street RHODES NSW 2138  680.0       2.0
# 496  rhodes           183/4 Timbrol Avenue RHODES NSW 2138  680.0       2.0
# 426  rhodes         701/87 Shoreline Drive RHODES NSW 2138  680.0       2.0
# 457  rhodes         407/63 Shoreline Drive RHODES NSW 2138  680.0       2.0
# 458  rhodes             30/2 Nina Grey Ave RHODES NSW 2138  680.0       2.0
# 461  rhodes         302/11 Shoreline Drive RHODES NSW 2138  680.0       2.0
# 427  rhodes          2210/42 Walker Street RHODES NSW 2138  680.0       2.0
# 497  rhodes           205/16 Sevier Avenue RHODES NSW 2138  690.0       2.0
# 455  rhodes          751/2 Marquet  Street RHODES NSW 2138  690.0       2.0
# 456  rhodes     Level 6/80 Rider Boulevard RHODES NSW 2138  690.0       2.0
# 417  rhodes         405/44 Shoreline Drive RHODES NSW 2138  695.0       2.0
# 408  rhodes            402/12 Shoreline Dr RHODES NSW 2138  700.0       2.0
# 453  rhodes  Level 4  406/16 Sevier Avenue RHODES NSW 2138  700.0       2.0
# 452  rhodes        1412/43 Shoreline Drive RHODES NSW 2138  700.0       2.0
# 451  rhodes          404/2 Shoreline Drive RHODES NSW 2138  700.0       2.0
# 424  rhodes         201/88 Rider Boulevard RHODES NSW 2138  700.0       2.0
# 416  rhodes        113/56-58 Walker Street RHODES NSW 2138  700.0       2.0
# 409  rhodes               205/11 Lewis Ave RHODES NSW 2138  700.0       2.0
# 466  rhodes             205 2 Lewis Avenue RHODES NSW 2138  700.0       2.0
# 454  rhodes         1105/7 Rider Boulevard RHODES NSW 2138  700.0       2.0
# 441  rhodes         402/42 Shoreline Drive RHODES NSW 2138  720.0       2.0
# 415  rhodes        705/52-54 WALKER STREET RHODES NSW 2138  720.0       2.0
# 414  rhodes              712/3 Timbrol Ave RHODES NSW 2138  730.0       2.0
# 449  rhodes             79 Shoreline Drive RHODES NSW 2138  750.0       2.0
# 413  rhodes           721/4 Marquet Street RHODES NSW 2138  800.0       2.0
# 423  rhodes              2308/46 Walker St RHODES NSW 2138  900.0       2.0
# 428  rhodes               201/2 Rider Blvd RHODES NSW 2138    NaN       2.0
# 429  rhodes             202/1 Gauthorpe St RHODES NSW 2138    NaN       2.0
# 431  rhodes                  86 Rider Blvd RHODES NSW 2138    NaN       2.0
# 433  rhodes               606/2 Walker St  RHODES NSW 2138    NaN       2.0
# 450  rhodes           A310/40 Shoreline Dr RHODES NSW 2138    NaN       2.0
# 459  rhodes              502/76 Rider Blvd RHODES NSW 2138    NaN       2.0
# 460  rhodes           509/46 Walker Street RHODES NSW 2138    NaN       2.0
# 463  rhodes         404/88 Rider Boulevard RHODES NSW 2138    NaN       2.0
# 465  rhodes          B402/10-16 Marquet st RHODES NSW 2138    NaN       2.0
# 469  rhodes            116/56-58 Walker St RHODES NSW 2138    NaN       2.0
# 486  rhodes      GG04/10-16 Marquet Street RHODES NSW 2138    NaN       2.0
#
#      Bathrooms  Parkings
# 494        1.0       2.0
# 480        1.0       1.0
# 432        1.0       1.0
# 477        1.0       1.0
# 500        2.0       1.0
# 474        2.0       1.0
# 475        2.0       1.0
# 499        1.0       1.0
# 472        2.0       1.0
# 473        2.0       1.0
# 471        1.0       1.0
# 419        2.0       1.0
# 468        2.0       1.0
# 430        1.0       1.0
# 467        2.0       1.0
# 498        2.0       1.0
# 421        2.0       1.0
# 418        2.0       1.0
# 464        2.0       1.0
# 462        1.0       1.0
# 425        2.0       2.0
# 496        2.0       2.0
# 426        2.0       1.0
# 457        1.0       1.0
# 458        2.0       1.0
# 461        2.0       1.0
# 427        1.0       1.0
# 497        2.0       1.0
# 455        2.0       1.0
# 456        2.0       1.0
# 417        2.0       1.0
# 408        2.0       1.0
# 453        2.0       1.0
# 452        2.0       1.0
# 451        2.0       1.0
# 424        2.0       1.0
# 416        2.0       1.0
# 409        2.0       1.0
# 466        2.0       1.0
# 454        2.0       1.0
# 441        1.0       1.0
# 415        2.0       1.0
# 414        2.0       1.0
# 449        2.0       1.0
# 413        2.0       1.0
# 423        2.0       1.0
# 428        2.0       1.0
# 429        2.0       1.0
# 431        2.0       1.0
# 433        2.0       1.0
# 450        2.0       1.0
# 459        2.0       1.0
# 460        1.0       1.0
# 463        2.0       1.0
# 465        2.0       1.0
# 469        2.0       1.0
# 486        1.0       1.0
